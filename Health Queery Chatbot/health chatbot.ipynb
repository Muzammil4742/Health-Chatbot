# %%
# !pip install requests

# %%
import requests
print("Requests is ready")
# Out:
# Requests is ready

# %%
from getpass import getpass

HF_TOKEN = getpass("Enter your Hugging Face API token: ")
# Out:
# Enter your Hugging Face API token: ··········

# %%
if HF_TOKEN:
    print("Token stored successfully")
else:
    print("Token missing")
# Out:
# Token stored successfully

# %%
# !pip install -q huggingface_hub

# %%
from huggingface_hub import InferenceClient

# %%
client = InferenceClient(
    model="google/flan-t5-base",
    token=HF_TOKEN
)

# %%
# !pip install -q transformers torch

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "mistralai/Mistral-7B-Instruct-v0.3"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
def generate_health_response(user_question):
    prompt = f"""
You are a helpful and friendly health assistant.
Answer clearly, simply, and safely.
Do not give diagnosis or dosage.
Include disclaimer: "This information is for educational purposes only and is not medical advice."

Question: {user_question}
Answer:
"""
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        do_sample=True,
        temperature=0.7,
        top_p=0.9
    )
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response.strip()

# %%
print("Welcome to the General Health Query Chatbot!")
print("Type 'exit' to quit at any time.\n")

while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye! Stay healthy 😊")
        break
    answer = generate_health_response(user_input)
    print("Chatbot:", answer)
# Out:
# Welcome to the General Health Query Chatbot!
# Type 'exit' to quit at any time.
#
# You: What cause sore throat?
# Chatbot: You are a helpful and friendly health assistant.
# Answer clearly, simply, and safely.
# Do not give diagnosis or dosage.
# Include disclaimer: "This information is for educational purposes only and is not medical advice."
#
# Question: What cause sore throat?
# Answer:
# Sore throat is a common condition that may be caused by many different causes.
# It is common for young people to have mild or moderate throat pain.
# It is important to note that the symptoms of sore throat vary from person to person, and may include:
# - Pain in the throat that can range from mild to severe.
# - Pains in the throat that can range from mild to severe.
# - Pains in the throat that can range from mild to severe.
# - Pains in the throat that can
# You: Is panadol good for children
# Chatbot: You are a helpful and friendly health assistant.
# Answer clearly, simply, and safely.
# ...
